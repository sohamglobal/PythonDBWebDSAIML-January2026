# %%
pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 1.9 MB/s eta 0:00:00
# ...

# %%
import pymysql

# %%
con=pymysql.connect(host='pymyservice-mysql-python-0226.g.aivencloud.com',port=17577,user='praffull',password='AVNS_wBJdNDhkoHduUD3Z3z2',database='sharayudb')

# %%
curs=con.cursor()

# %%
no=int(input('Enter account number : '))
nm=input('Enter account name : ')
ty=input('Enter account type : ')
bl=float(input('Enter balance : '))
# Out:
# Enter account number : 1229
# Enter account name : Apurva Deo
# Enter account type : saving
# Enter balance : 83100

# %%
curs.execute(f"insert into accounts values({no},'{nm}','{ty}',{bl})")
# Out:
# 1

# %%
con.commit()

# %%
rno=int(input('Enter roll number : '))
snm=input('Enter student name : ')
ct=input('Enter city : ')
co=input('Enter course : ')
fs=float(input('Enter fees : '))
# Out:
# Enter roll number : 103
# Enter student name : Sarvesh Thakare
# Enter city : Nanded
# Enter course : GenAI
# Enter fees : 4500

# %%
curs.execute(f"insert into students values({rno},'{snm}','{ct}','{co}',{fs})")
# Out:
# 1

# %%
con.commit()

# %%
nm=input('Enter name : ')
srv=input('Enter service : ')
mob=input('Enter mobile number : ')
# Out:
# Enter name : vijay
# Enter service : workshop
# Enter mobile number : 8756466321

# %%
curs.execute(f"insert into enquiries(name,service,mobile) values('{nm}','{srv}','{mob}')")
# Out:
# 1

# %%
con.commit()

# %%
con.close()
