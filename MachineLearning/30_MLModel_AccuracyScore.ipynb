# %%
import pandas
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# **Loading data from csv dataset into pandas dataframe**

# %%
url="https://raw.githubusercontent.com/sohamglobal/datasets/refs/heads/main/moviechoice.csv"
df=pandas.read_csv(url)
print(df.head())
# Out:
#    gender  age  locality    genre
# 0       1   18         1  Fantasy
# 1       1   20         1  Fantasy
# 2       1   23         1  Fantasy
# 3       1   25         1  Fantasy
# 4       1   18         2   Comedy

# %% [markdown]
# **Divide features and labels**

# %%
features=df[['gender','age','locality']]
labels=df['genre']

# %% [markdown]
# **Split the features and labels for testing**

# %%
total=0
for i in range(1,11):
  F_train,F_test,L_train,L_test=train_test_split(features,labels,test_size=0.2)
  model=DecisionTreeClassifier()
  model.fit(F_train.values,L_train.values)
  predicted_result=model.predict(F_test.values)
  score=accuracy_score(predicted_result,L_test)
  #print(score)
  total+=score

avg=(total/10)*100
print('Average accuracy score of the ML model : %.2f%%' %avg)
# Out:
# Average accuracy score of the ML model : 92.67%
