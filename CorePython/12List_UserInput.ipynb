# %%
friends=[]
cho=''

while cho.lower()!='no':
  nm=input('Enter friend name : ')
  friends.append(nm)
  cho=input('Do you want to add more friends? (yes/no) : ')
else:
  print(friends)
# Out:
# Enter friend name : joe root
# Do you want to add more friends? (yes/no) : yes
# Enter friend name : jos buttler
# Do you want to add more friends? (yes/no) : yes
# Enter friend name : mohammed salah
# Do you want to add more friends? (yes/no) : yes
# Enter friend name : steve smith
# Do you want to add more friends? (yes/no) : no
# ['joe root', 'jos buttler', 'mohammed salah', 'steve smith']

# %%
s=input('Enter name : ')
if s in friends:
  print('friend found')
else:
  print('friend not found...added')
  friends.append(s)

print(friends)
# Out:
# Enter name : soham
# friend not found...added
# ['joe root', 'jos buttler', 'mohammed salah', 'steve smith', 'soham']
