# %%
dic={}
print(type(dic))
dic1=dict()
print(type(dic1))
# Out:
# <class 'dict'>
# <class 'dict'>

# %%
emp={
    "empname":"Praffull",
    "department":"Marketing",
    "location":"Mumbai",
    "salary":31500
}
print(emp)
print(type(emp))
# Out:
# {'empname': 'Praffull', 'department': 'Marketing', 'location': 'Mumbai', 'salary': 31500}
# <class 'dict'>

# %%
stud=dict(studname='sharayu',course='core java',feespaid=False)
print(stud)
print(type(stud))
# Out:
# {'studname': 'sharayu', 'course': 'core java', 'feespaid': False}
# <class 'dict'>

# %%
e={
    "empnm":"Shailaja",
    "department":"development",
    "skillset":["asp.net core","sql server","azure"],
    "location":"dubai"
}
print(e)
print(type(e))
# Out:
# {'empnm': 'Shailaja', 'department': 'development', 'skillset': ['asp.net core', 'sql server', 'azure'], 'location': 'dubai'}
# <class 'dict'>

# %%
player={
    "playernm":"Dominik Szoboszlai",
    "club":"Liverpool",
    "position":"midfielder",
    "healthparam":{
        "age":26,
        "height":175,
        "weight":64
    },
    "contractends":"June 2027"

}

print(player)
print(type(player))
# Out:
# {'playernm': 'Dominik Szoboszlai', 'club': 'Liverpool', 'position': 'midfielder', 'healthparam': {'age': 26, 'height': 175, 'weight': 64}, 'contractends': 'June 2027'}
# <class 'dict'>

# %%
k=['patnm','age','city']
v=['john doe','47','chicago']
patient=dict(zip(k,v))
print(patient)
# Out:
# {'patnm': 'john doe', 'age': '47', 'city': 'chicago'}

# %%
patient['age']=47
print(patient)
# Out:
# {'patnm': 'john doe', 'age': 47, 'city': 'chicago'}
