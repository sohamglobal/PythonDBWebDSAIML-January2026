# %% [markdown]
# **retrieve data from selected rows and columns**

# %%
import pandas

# %%
url="http://sohamspring.azurewebsites.net/api/accounts/all"
df=pandas.read_json(url)
print(df.head())
# Out:
#    accno               accnm  acctype  balance
# 0   1001    sachin tendulkar   saving    45000
# 1   1002     maria sharapova    fixed    23100
# 2   1003    mitchell johnson  current    15300
# 3   1004         edan hazard   saving    41300
# 4   1005  robert lewandowski   saving    21600

# %%
print(df.shape)
# Out:
# (51, 4)

# %%
print(df['accnm'].head(3))
# Out:
# 0    sachin tendulkar
# 1     maria sharapova
# 2    mitchell johnson
# Name: accnm, dtype: object

# %%
# print(df[['accnm','balance']])
print(df[['accnm','balance']].tail())
# Out:
#              accnm  balance
# 46    ravi shastri    55040
# 47   harsha bhogle    87980
# 48    irfan pathan    75000
# 49     patric jane    87500
# 50  manmohan singh   300000

# %%
print(df.loc[3])
# Out:
# accno             1004
# accnm      edan hazard
# acctype         saving
# balance          41300
# Name: 3, dtype: object

# %%
print(df.loc[5:9])
# Out:
#    accno          accnm  acctype  balance
# 5   1006  gabriel jesus    fixed    37100
# 6   1008  marcos alonso   saving    33900
# 7   1009     david luiz  current    28400
# 8   1010    steve smith    fixed    61150
# 9   1012    zaheer khan   saving    22570

# %%
print(df.loc[15,'accnm'])
# Out:
# cesar azpilicueta

# %%
print(df.loc[31:35,'accnm'])
# Out:
# 31    raheem sterling
# 32         harry kane
# 33          dele alli
# 34        hugo lloris
# 35         bill gates
# Name: accnm, dtype: object

# %%
print(df.loc[31:35,['accnm','balance']])
# Out:
#               accnm  balance
# 31  raheem sterling    62994
# 32       harry kane    78751
# 33        dele alli    96637
# 34      hugo lloris    84552
# 35       bill gates    93119
