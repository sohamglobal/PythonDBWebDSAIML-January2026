# %%
tech={'java','python','jpa','spring','pandas','openai','spring','jpa'}
print(tech)
print(type(tech))
# Out:
# {'spring', 'jpa', 'openai', 'pandas', 'java', 'python'}
# <class 'set'>

# %%
empty=set()
print(type(empty))
# Out:
# <class 'set'>

# %%
mixed={9,"praffull",68.14,True}

# %%
mixed.add('7391966656')

# %%
print(mixed)
# Out:
# {True, 68.14, 9, '7391966656', 'praffull'}

# %%
print(mixed[4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1282614923.py in <cell line: 0>()
# ----> 1 print(mixed[4])
#
# TypeError: 'set' object is not subscriptable

# %%
mixed.remove(True)
print(mixed)
# Out:
# {68.14, 9, '7391966656', 'praffull'}

# %%
import sys

s={1,2,3,4,5}
l=[1,2,3,4,5]
t=(1,2,3,4,5)
r=range(5)

print(sys.getsizeof(s))
print(sys.getsizeof(l))
print(sys.getsizeof(t))
print(sys.getsizeof(r))
# Out:
# 472
# 104
# 80
# 48

# %%
tech={'java','python','jpa','spring','pandas','openai','spring','jpa'}
print(len(tech))
print(max(tech))
print(min(tech))
# Out:
# 6
# spring
# java
