# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 15.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 8.9 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient
client=MongoClient("mongodb+srv://praffull:mongodb913@sharayucluster.fib907c.mongodb.net/?appName=sharayucluster")
db1=client["sohamdb"]
coll_users=db1["users"]

# %%
coll_users.delete_one({'userid':'foden'})
# Out:
# DeleteResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000284'), 'opTime': {'ts': Timestamp(1773196769, 1), 't': 644}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1773196769, 1), 'signature': {'hash': b'\xfc\x8d\xdc\xb7\x0e\xd4\x85\x82iC2\xee\x7f\x06\xca\xbb\xd9\x85g:', 'keyId': 7568985758678122503}}, 'operationTime': Timestamp(1773196769, 1)}, acknowledged=True)
