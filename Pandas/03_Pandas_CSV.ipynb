# %%
import pandas

# %%
dataset_url="https://raw.githubusercontent.com/sohamglobal/datasets/refs/heads/main/shopping_behavior.csv"

# %%
df=pandas.read_csv(dataset_url)
print(df)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
url="https://raw.githubusercontent.com/sohamglobal/datasets/refs/heads/main/alphacustomers.csv"

# %%
df=pandas.read_csv(url)

# %%
print(df)
# Out:
#     customer_id           full_name         dob  age  gender      mobile  \
# 0             1          Vijay Kale  1992-08-15   33    male  9876543210
# 1             2  Amit Hari Bachchan  1941-10-11   80    male  7122245637
# 2             3      Ravindra Patil  1985-04-12   40    male  9876500001
# 3             4          Priya Nair  1990-09-23   35  female  9876500002
# 4             5          Amit Verma  1995-07-11   30    male  9876500003
# 5             6      Sneha Kulkarni  1988-03-05   37  female  9876500004
# 6             7          Ravi Patel  1978-12-19   46    male  9876500005
# 7             8        Anjali Gupta  1999-11-02   25  female  9876500006
# 8             9         Vikas Yadav  1982-06-15   43    male  9876500007
# 9            10         Deepa Reddy  1994-08-29   31  female  9876500008
# 10           11         Karan Singh  1989-01-10   36    male  9876500009
# 11           12      Meena Deshmukh  1996-12-30   28  female  9876500010
# ...
