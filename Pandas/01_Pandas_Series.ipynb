# %% [markdown]
# For local pandas programming "pip install pandas"

# %%
import pandas

# %%
s1=pandas.Series([9,26,1,13,30,45,15])

# %%
print(s1)
# Out:
# 0     9
# 1    26
# 2     1
# 3    13
# 4    30
# 5    45
# 6    15
# dtype: int64

# %%
print(s1.dtype)
# Out:
# int64

# %%
s2=pandas.Series(['praffull','java','python','sql'])

# %%
print(s2)
# Out:
# 0    praffull
# 1        java
# 2      python
# 3         sql
# dtype: object

# %% [markdown]
# the default labels are 0,1,2,3...

# %%
s3=pandas.Series(['java','springboot','mongodb','windows','azure'],
                 index=['language','mvc','db','os','cloud'])

# %%
print(s3)
# Out:
# language          java
# mvc         springboot
# db             mongodb
# os             windows
# cloud            azure
# dtype: object

# %%
s4=pandas.Series([68.14,89.22,75.59],
                 index=['praffull','sharayu','shailaja'])

# %%
print(s4)
# Out:
# praffull    68.14
# sharayu     89.22
# shailaja    75.59
# dtype: float64

# %%
s5=pandas.Series(['sohamglobal',22,91.55,True])

# %%
print(s5.dtype)
# Out:
# object

# %%
print(s5)
# Out:
# 0    sohamglobal
# 1             22
# 2          91.55
# 3           True
# dtype: object
