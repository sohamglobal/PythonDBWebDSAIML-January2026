# %%
dic={101: 'Jos Buttler', 102: 'Pat Cummins', 103: 'Joe Root', 104: 'Steve Smith', 105: 'Ben Stokes'}
print(dic)
# Out:
# {101: 'Jos Buttler', 102: 'Pat Cummins', 103: 'Joe Root', 104: 'Steve Smith', 105: 'Ben Stokes'}

# %%
if 106 in dic:
  print(dic[103])
else:
  print('key not found')
# Out:
# key not found

# %%
company={
    "IT":{
        "manager":"praffull",
        "employees":["sharayu","sneha","nupur","javed"]
    },
    "HR":{
        "manager":"shailaja",
        "employees":["megha","manali","rita"]
    }
}

# %%
print(company["IT"])
# Out:
# {'manager': 'praffull', 'employees': ['sharayu', 'sneha', 'nupur', 'javed']}

# %%
print(company["IT"]["manager"])
# Out:
# praffull

# %%
print(company["IT"]["employees"])
# Out:
# ['sharayu', 'sneha', 'nupur', 'javed']

# %%
print(company["IT"]["employees"][0])
# Out:
# sharayu

# %%
for nm in company["IT"]["employees"]:
  print(nm.upper())
# Out:
# SHARAYU
# SNEHA
# NUPUR
# JAVED
