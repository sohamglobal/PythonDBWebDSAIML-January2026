# %%
import numpy
import pandas

# %%
df=pandas.DataFrame(numpy.random.rand(10,4),columns=['mumbai','chennai','kolkata','hyderabad'])
print(df)
# Out:
#      mumbai   chennai   kolkata  hyderabad
# 0  0.229867  0.798793  0.992511   0.906432
# 1  0.848703  0.469075  0.354184   0.655924
# 2  0.488868  0.173366  0.012165   0.593694
# 3  0.553420  0.496981  0.026152   0.202190
# 4  0.912125  0.252820  0.722879   0.027031
# 5  0.250800  0.666132  0.418405   0.398896
# 6  0.242151  0.591676  0.074517   0.519572
# 7  0.134343  0.108839  0.744026   0.235792
# 8  0.810532  0.817509  0.384429   0.184092
# 9  0.857366  0.005997  0.671566   0.933829
