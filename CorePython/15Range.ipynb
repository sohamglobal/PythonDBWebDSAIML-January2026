# %%
numbers=range(5)

print(numbers)
print(type(numbers))
# Out:
# range(0, 5)
# <class 'range'>

# %%
for n in numbers:
  print(n)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
numbers=range(9,25,2)
for n in numbers:
  print(n)
# Out:
# 9
# 11
# 13
# 15
# 17
# 19
# 21
# 23
