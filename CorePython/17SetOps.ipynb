# %%
a={1,2,3,4,5}
b={4,5,6,7,8}

res=a.union(b)
print(res)

res=a.intersection(b)
print(res)

res=a.difference(b)
print(res)

res=a.symmetric_difference(b)
print(res)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}
# {4, 5}
# {1, 2, 3}
# {1, 2, 3, 6, 7, 8}
