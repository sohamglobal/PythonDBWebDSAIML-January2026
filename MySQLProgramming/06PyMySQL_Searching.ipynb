# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading pymysql-1.1.2-py3-none-any.whl.metadata (4.3 kB)
# Downloading pymysql-1.1.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.2

# %%
import pymysql

# %%
connection=pymysql.connect(host='pymyservice-mysql-python-0226.g.aivencloud.com',port=17577,user='praffull',password='AVNS_wBJdNDhkoHduUD3Z3z2',database='sharayudb')

# %%
cursor=connection.cursor()

# %%
no=int(input('Enter account number to search : '))
cursor.execute(f"select * from accounts where accno={no}")
data=cursor.fetchone()
if data:
  print(data)
else:
  print('account does not exist')
# Out:
# Enter account number to search : 1199
# (1199, 'Phil Foden', 'saving', 61000.0)

# %%
typ=input('Enter account type : ')
cursor.execute(f"select * from accounts where acctype='{typ}'")
data=cursor.fetchall()
print(data)
# Out:
# Enter account type : ppf
# ((1179, 'Stuart Broad', 'ppf', 70000.0), (1184, 'Pat Cummins', 'ppf', 47000.0), (1188, 'Aaron Finch', 'ppf', 36000.0), (1194, 'Kevin De Bruyne', 'ppf', 72000.0), (1198, 'Bukayo Saka', 'ppf', 52000.0), (1203, 'Reece James', 'ppf', 57000.0), (1207, 'Son Heung-min', 'ppf', 60000.0), (1212, 'Ollie Watkins', 'ppf', 62000.0), (1219, 'Alex Carey', 'ppf', 52000.0), (1224, 'Dominic Calvert-Lewin', 'ppf', 43000.0))

# %%
typ=input('Enter account type : ')
amt=float(input('Enter amount : '))
cursor.execute(f"select * from accounts where acctype='{typ}' and balance>{amt}")
data=cursor.fetchall()
print(data)
# Out:
# Enter account type : saving
# Enter amount : 55000
# ((1183, 'Steve Smith', 'saving', 73000.0), (1193, 'Marcus Rashford', 'saving', 58000.0), (1199, 'Phil Foden', 'saving', 61000.0), (1214, 'Trent Alexander-Arnold', 'saving', 70500.0), (1220, 'Josh Hazlewood', 'saving', 67500.0), (1223, 'Mitchell Marsh', 'saving', 58000.0), (1228, 'Shailaja', 'saving', 75400.0), (1229, 'Apurva Deo', 'saving', 79900.0))

# %%
comp=input('Enter company : ')
cursor.execute(f"select * from cars where company='{comp}'")
data=cursor.fetchall()
print(data)
# Out:
# Enter company : Skoda
# (('sk181', 'Kushaq', 'Skoda', 1158000.0), ('sk182', 'Superb', 'Skoda', 3416000.0), ('sk183', 'Kodiaq', 'Skoda', 3749000.0))

# %%
dis=input('Enter keyword relating to the problem : ')
cursor.execute(f"select * from patients where disease like '%{dis}%'")
data=cursor.fetchall()
print(data)
# Out:
# Enter keyword relating to the problem : heart
# ((101, 'Alice', 45, 'Heart Disease', 1), (102, 'Bob', 50, 'Heart Attack', 1), (110, 'Jack', 65, 'Heart Disease', 1), (116, 'Paul', 48, 'Heart Block', 1))

# %%
connection.close()
