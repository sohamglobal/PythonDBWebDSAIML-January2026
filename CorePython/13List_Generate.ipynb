# %%
lst=[3,12,45,9,15,26,13]
sq=[]

for n in lst:
  sq.append(n*n)

print(sq)
# Out:
# [9, 144, 2025, 81, 225, 676, 169]

# %%
lst=[3,12,45,9,15,26,13]
sq=[n**3 for n in lst]
print(sq)
# Out:
# [27, 1728, 91125, 729, 3375, 17576, 2197]

# %%
nms=['praffull','sharayu','soham','shailaja']
u=[nm.upper() for nm in nms]
print(u)
# Out:
# ['PRAFFULL', 'SHARAYU', 'SOHAM', 'SHAILAJA']

# %%
lst=[9,13,26,1,45,10,30,15,18,25]
odd=[x for x in lst if x%2==1]
print(odd)
# Out:
# [9, 13, 1, 45, 15, 25]

# %%
lst=[9,13,26,1,-45,-10,30,15,-18,25]
neg=[x for x in lst if x<0]
print(neg)
# Out:
# [-45, -10, -18]
