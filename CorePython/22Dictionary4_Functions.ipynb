# %%
student={'name':'praffull','qualification':'mba','course':'data science'}
print(student)
# Out:
# {'name': 'praffull', 'qualification': 'mba', 'course': 'data science'}

# %%
print(student.keys())

for k in student.keys():
  print(k)
# Out:
# dict_keys(['name', 'qualification', 'course'])
# name
# qualification
# course

# %%
print(student.values())

for v in student.values():
  print(v)
# Out:
# dict_values(['praffull', 'mba', 'data science'])
# praffull
# mba
# data science

# %%
print(student.items())
# Out:
# dict_items([('name', 'praffull'), ('qualification', 'mba'), ('course', 'data science')])

# %%
for i in student.items():
  print(i)
# Out:
# ('name', 'praffull')
# ('qualification', 'mba')
# ('course', 'data science')

# %%
subjects=['science','maths','english']
marks=dict.fromkeys(subjects,0)
print(marks)
# Out:
# {'science': 0, 'maths': 0, 'english': 0}

# %%
marks['maths']+=5
print(marks)
# Out:
# {'science': 0, 'maths': 5, 'english': 0}
