# %%
empty=()
print(type(empty))
coord=(10,20)
print(type(coord))
single=(9,)
print(type(single))
mixed=(9,'praffull',68.14,True)
print(mixed)
print(type(mixed))
nested=((1,2),(3,4))
print(nested)
print(type(nested))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# (9, 'praffull', 68.14, True)
# <class 'tuple'>
# ((1, 2), (3, 4))
# <class 'tuple'>

# %%
t=(9,'praffull',['java','python'])
print(t)
print(type(t))
t[2].append('spring')
print(t)
# Out:
# (9, 'praffull', ['java', 'python'])
# <class 'tuple'>
# (9, 'praffull', ['java', 'python', 'spring'])

# %%
tup=(1726,'praffull','saving','dadar mumbai',43100.50)
print(len(tup))
# Out:
# 5

# %%
tup=('praffull','sharayu','soham','shailaja','megha')
print(max(tup))
print(min(tup))
# Out:
# soham
# megha

# %%
for nm in tup:
  print(nm)
# Out:
# praffull
# sharayu
# soham
# shailaja
# megha

# %%
t=(5,1,2,4,2,7,3)
print(sorted(t))
# Out:
# [1, 2, 2, 3, 4, 5, 7]

# %%
t1=(1,2,3)
t2=(4,5,6)
t3=t1+t2
print(t3)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
print(t3[0:3])
# Out:
# (1, 2, 3)

# %% [markdown]
# **Storage comparison**

# %%
import sys

lst=[1,2,3,4,5]
tup=(1,2,3,4,5)

print(sys.getsizeof(lst))
print(sys.getsizeof(tup))
# Out:
# 104
# 80

# %%
tup=('praffull','sharayu','soham','shailaja','megha','soham')
print(tup.count('soham'))
print(tup.index('praffull'))
# Out:
# 2
# 0

# %%
import timeit

list_time=timeit.timeit('x=[1,2,3,4,5]',number=100000)
tup_time=timeit.timeit('x=(1,2,3,4,5)',number=100000)

print(list_time)
print(tup_time)
# Out:
# 0.006060850000267237
# 0.0014933420002307685
