# %%
import pandas

# %%
file=pandas.ExcelFile("myshop.xlsx")
df=file.parse("mobiles")
print(df)
# Out:
#     S.No     Brand          Model Name             Color  RAM (GB)  ROM (GB)  \
# 0      1   Samsung    Galaxy S24 Ultra    Titanium Black        12       256
# 1      2   Samsung         Galaxy S24+     Cobalt Violet        12       256
# 2      3   Samsung          Galaxy S24       Marble Gray         8       128
# 3      4   Samsung          Galaxy A55      Awesome Navy         8       128
# 4      5   Samsung          Galaxy A35   Awesome Iceblue         6       128
# 5      6   Samsung          Galaxy M55    Midnight Black         8       128
# 6      7   Samsung          Galaxy F55     Apricot Crush         8       256
# 7      8     Apple   iPhone 15 Pro Max    Black Titanium         8       256
# 8      9     Apple       iPhone 15 Pro    White Titanium         8       128
# 9     10     Apple           iPhone 15              Pink         6       128
# 10    11     Apple      iPhone 15 Plus            Yellow         6       128
# ...

# %%
df.to_pickle("mobilestock")
print("data frame data stored in a file")
# Out:
# data frame data stored in a file
