# %%
import pandas
from sklearn.cluster import KMeans

# %%
url="https://raw.githubusercontent.com/sohamglobal/datasets/refs/heads/main/testcricketers.csv"
df=pandas.read_csv(url)
print(df.head(10))
# Out:
#                  Player Country  TestRuns  TestWickets
# 0         Glenn McGrath     AUS       641          563
# 1        Jacques Kallis      SA     13289          292
# 2             Kapil Dev     IND      5248          434
# 3        James Anderson     ENG      1350          704
# 4           Wasim Akram     PAK      2898          414
# 5         Ricky Ponting     AUS     13378            5
# 6            Ben Stokes     ENG      6320          200
# 7        Curtly Ambrose      WI      1400          405
# 8          Rahul Dravid     IND     13288            1
# 9  Muttiah Muralitharan      SL      1267          800

# %%
X=df[['TestRuns','TestWickets']]

# %%
km=KMeans(n_clusters=3,random_state=42)
df['Cluster']=km.fit_predict(X)

# %%
print(df)
# Out:
#                   Player Country  TestRuns  TestWickets  Cluster
# 0          Glenn McGrath     AUS       641          563        0
# 1         Jacques Kallis      SA     13289          292        1
# 2              Kapil Dev     IND      5248          434        2
# 3         James Anderson     ENG      1350          704        0
# 4            Wasim Akram     PAK      2898          414        0
# 5          Ricky Ponting     AUS     13378            5        1
# 6             Ben Stokes     ENG      6320          200        2
# 7         Curtly Ambrose      WI      1400          405        0
# 8           Rahul Dravid     IND     13288            1        1
# 9   Muttiah Muralitharan      SL      1267          800        0
# 10         Alastair Cook     ENG     12472            1        1
# 11           Anil Kumble     IND      2506          619        0
# 12      Sachin Tendulkar     IND     15921           46        1
# 13        Daniel Vettori      NZ      4531          362        2
# 14      Kumar Sangakkara      SL     12400            0        1
# 15            Imran Khan     PAK      3807          362        2
# 16            Brian Lara      WI     11953            0        1
# 17            Ian Botham     ENG      5200          383        2
# 18           Steve Smith     AUS      9600           19        1
# 19           Shane Warne     AUS      3154          708        0
# 20           Virat Kohli     IND      9200            4        1
# 21              Joe Root     ENG     11400           65        1
# 22         Shaun Pollock      SA      3781          421        2
# 23            Dale Steyn      SA      1250          439        0
# 24   Ravichandran Ashwin     IND      3474          537        2

# %%
print(df.groupby('Cluster')[['TestRuns','TestWickets']].mean())
# Out:
#          TestRuns  TestWickets
# Cluster
# 0         1808.25   581.500000
# 1        12290.10    43.300000
# 2         4623.00   385.571429

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['TestRuns'],df['TestWickets'],c=df['Cluster'])
plt.xlabel('Runs')
plt.ylabel('Wickets')
plt.title('Unsupervised KMeans clustering of cricketers')
plt.show()

# %%
newplayer={'TestRuns':[14500],'TestWickets':[51]}
np=pandas.DataFrame(newplayer)
result_cluster=km.predict(np)
print(result_cluster)

if result_cluster[0]==0:
  print('Bowler')
elif result_cluster[0]==1:
  print('Batter')
else:
  print('All Rounder')
# Out:
# [1]
# Batter
