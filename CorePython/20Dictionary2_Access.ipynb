# %%
student={"studnm":"soham","course":"spark","fees":12500,"mode":"live online"}
print(student)
# Out:
# {'studnm': 'soham', 'course': 'spark', 'fees': 12500, 'mode': 'live online'}

# %%
print(student["studnm"])
# Out:
# soham

# %%
print(student["course"])
# Out:
# spark

# %%
print(student.get("mode"))
# Out:
# live online

# %%
print(student.get("mobile"))
# Out:
# None

# %%
print(student.get("qualification","Not Available"))
# Out:
# Not Available

# %%
player={
    "playernm":"Dominik Szoboszlai",
    "club":"Liverpool",
    "position":"midfielder",
    "healthparam":{
        "age":26,
        "height":175,
        "weight":64
    },
    "contractends":"June 2027"

}

# %%
print(player["healthparam"]["age"])
# Out:
# 26
