# %%
class Praffull:
  def __init__(self,name):
    print(f"your name is {name} and length is {len(name)}")

# %%
class Sharayu(Praffull):
  def __init__(self):
    super().__init__('soham')
    print("derived class sharayu constructor running")

# %%
obj=Sharayu()
# Out:
# your name is soham and length is 5
# derived class sharayu constructor running
