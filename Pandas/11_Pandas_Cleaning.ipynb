# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 11.7 MB/s eta 0:00:00
# ...

# %%
import pandas
from pymongo import MongoClient

# %%
client=MongoClient("mongodb+srv://praffull:mongodb913@sharayucluster.fib907c.mongodb.net/?appName=sharayucluster")

# %%
db=client["spiderdb"]

# %%
collfilms=db["films"]

# %%
data=list(collfilms.find())

# %% [markdown]
# **Load data**

# %%
df=pandas.DataFrame(data)
print(df)
# Out:
#     _id                filmnm category  releaseyr      written  \
# 0   151                sholay   action       1975  salim javed
# 1   152                    pk   comedy       2014          NaN
# 2   153            the matrix   action       1999          NaN
# 3   154         mughal e azam  romance       1960          NaN
# 4   155      mi5 rogue nation   action       2015          NaN
# 5   156                  maya  romance       1961          NaN
# 6   157     1942 a love story  romance       1994          NaN
# 7   158  chalti ka naam gaadi   comedy       1958          NaN
# 8   159             golmaal 3   comedy       2010          NaN
# 9   160                 bhoot   horror       2003          NaN
# 10  161               silsila  romance       1981          NaN
# 11  162                swades    drama       2004          NaN
# 12  163                  1917      war       2019          NaN
#
#                  director             actor              actress  \
# ...

# %% [markdown]
# **Inspect data**

# %%
df.head(3)
# Out:
#    _id      filmnm category  releaseyr      written         director  \
# 0  151      sholay   action       1975  salim javed     ramesh sippy
# 1  152          pk   comedy       2014          NaN  rajkumar hirani
# 2  153  the matrix   action       1999          NaN   wachowski bros
#
#               actor           actress       music     villain  budgetmn  \
# 0  amitabh bachchan      jaya bhaduri  r d burman  amjad khan      30.0
# 1         amir khan    anushka sharma         NaN         NaN     850.0
# 2      keanu reeves  carrie-anne moss         NaN         NaN    4725.0
#
#    collectionmn comedian cinematography
# 0         410.0      NaN            NaN
# 1        8540.0      NaN            NaN
# 2       34950.0      NaN            NaN

# %%
print(df.shape)
# Out:
# (13, 14)

# %%
print(df.columns)
# Out:
# Index(['_id', 'filmnm', 'category', 'releaseyr', 'written', 'director',
#        'actor', 'actress', 'music', 'villain', 'budgetmn', 'collectionmn',
#        'comedian', 'cinematography'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# _id                object
# filmnm             object
# category           object
# releaseyr           int64
# written            object
# director           object
# actor              object
# actress            object
# music              object
# villain            object
# budgetmn          float64
# collectionmn      float64
# comedian           object
# cinematography     object
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   _id             13 non-null     object
#  1   filmnm          13 non-null     object
#  2   category        13 non-null     object
#  3   releaseyr       13 non-null     int64
#  4   written         1 non-null      object
#  5   director        12 non-null     object
#  6   actor           12 non-null     object
#  7   actress         11 non-null     object
#  8   music           8 non-null      object
#  9   villain         2 non-null      object
#  10  budgetmn        9 non-null      float64
#  11  collectionmn    9 non-null      float64
#  12  comedian        1 non-null      object
#  13  cinematography  1 non-null      object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 1.6+ KB
# None

# %%
print(pandas.isnull(df))
# Out:
#       _id  filmnm  category  releaseyr  written  director  actor  actress  \
# 0   False   False     False      False    False     False  False    False
# 1   False   False     False      False     True     False  False    False
# 2   False   False     False      False     True     False  False    False
# 3   False   False     False      False     True     False  False    False
# 4   False   False     False      False     True     False  False    False
# 5   False   False     False      False     True      True  False    False
# 6   False   False     False      False     True     False  False    False
# 7   False   False     False      False     True     False  False    False
# 8   False   False     False      False     True     False  False    False
# 9   False   False     False      False     True     False   True    False
# 10  False   False     False      False     True     False  False    False
# 11  False   False     False      False     True     False  False     True
# ...

# %%
df.isnull().sum()
# Out:
# _id                0
# filmnm             0
# category           0
# releaseyr          0
# written           12
# director           1
# actor              1
# actress            2
# music              5
# villain           11
# budgetmn           4
# collectionmn       4
# comedian          12
# cinematography    12
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(64)

# %% [markdown]
# **Handle missing values - remove rows with null values**

# %%
res=df.dropna()
print(res)
# Out:
# Empty DataFrame
# Columns: [_id, filmnm, category, releaseyr, written, director, actor, actress, music, villain, budgetmn, collectionmn, comedian, cinematography]
# Index: []

# %% [markdown]
# remove cols with null values

# %%
res=df.dropna(axis=1)
print(res)
# Out:
#     _id                filmnm category  releaseyr
# 0   151                sholay   action       1975
# 1   152                    pk   comedy       2014
# 2   153            the matrix   action       1999
# 3   154         mughal e azam  romance       1960
# 4   155      mi5 rogue nation   action       2015
# 5   156                  maya  romance       1961
# 6   157     1942 a love story  romance       1994
# 7   158  chalti ka naam gaadi   comedy       1958
# 8   159             golmaal 3   comedy       2010
# 9   160                 bhoot   horror       2003
# 10  161               silsila  romance       1981
# 11  162                swades    drama       2004
# 12  163                  1917      war       2019

# %%
df['actor'].fillna('unknown',inplace=True)
print(df)
# Out:
#     _id                filmnm category  releaseyr      written  \
# 0   151                sholay   action       1975  salim javed
# 1   152                    pk   comedy       2014          NaN
# 2   153            the matrix   action       1999          NaN
# 3   154         mughal e azam  romance       1960          NaN
# 4   155      mi5 rogue nation   action       2015          NaN
# 5   156                  maya  romance       1961          NaN
# 6   157     1942 a love story  romance       1994          NaN
# 7   158  chalti ka naam gaadi   comedy       1958          NaN
# 8   159             golmaal 3   comedy       2010          NaN
# 9   160                 bhoot   horror       2003          NaN
# 10  161               silsila  romance       1981          NaN
# 11  162                swades    drama       2004          NaN
# 12  163                  1917      war       2019          NaN
#
#                  director             actor              actress  \
# ...

# %%
res=df.dropna(axis=1)
print(res)
# Out:
#     _id                filmnm category  releaseyr             actor
# 0   151                sholay   action       1975  amitabh bachchan
# 1   152                    pk   comedy       2014         amir khan
# 2   153            the matrix   action       1999      keanu reeves
# 3   154         mughal e azam  romance       1960       dilip kumar
# 4   155      mi5 rogue nation   action       2015        tom cruise
# 5   156                  maya  romance       1961         dev anand
# 6   157     1942 a love story  romance       1994       anil kapoor
# 7   158  chalti ka naam gaadi   comedy       1958     koshore kumar
# 8   159             golmaal 3   comedy       2010       ajay devgan
# 9   160                 bhoot   horror       2003           unknown
# 10  161               silsila  romance       1981  amitabh bachchan
# 11  162                swades    drama       2004    shah rukh khan
# 12  163                  1917      war       2019     george mackay

# %%
data={'Name':['Jos','Joe','Ben','Steve',None,'Pat','Joe'],
      'Age':[34,32,None,34,None,None,32]}
df=pandas.DataFrame(data)
print(df)
# Out:
#     Name   Age
# 0    Jos  34.0
# 1    Joe  32.0
# 2    Ben   NaN
# 3  Steve  34.0
# 4   None   NaN
# 5    Pat   NaN
# 6    Joe  32.0

# %% [markdown]
# **Remove duplicate rows**

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
df=df.drop_duplicates()
print(df)
# Out:
#     Name   Age
# 0    Jos  34.0
# 1    Joe  32.0
# 2    Ben   NaN
# 3  Steve  34.0
# 4   None   NaN
# 5    Pat   NaN

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
print(df)
# Out:
#     Name        Age
# 0    Jos  34.000000
# 1    Joe  32.000000
# 2    Ben  33.333333
# 3  Steve  34.000000
# 4   None  33.333333
# 5    Pat  33.333333

# %% [markdown]
# **Fix the datatypes**

# %%
df['Age']=df['Age'].astype(int)
print(df)
# Out:
#     Name  Age
# 0    Jos   34
# 1    Joe   32
# 2    Ben   33
# 3  Steve   34
# 4   None   33
# 5    Pat   33

# %% [markdown]
# **Renaming columns**

# %%
df=pandas.read_pickle("mobilestock")
print(df.head(3))
# Out:
#    S.No    Brand        Model Name           Color  RAM (GB)  ROM (GB)  \
# 0     1  Samsung  Galaxy S24 Ultra  Titanium Black        12       256
# 1     2  Samsung       Galaxy S24+   Cobalt Violet        12       256
# 2     3  Samsung        Galaxy S24     Marble Gray         8       128
#
#             Processor  Screen Size (inches)  Price (INR)
# 0  Snapdragon 8 Gen 3                   6.8     124999.0
# 1  Snapdragon 8 Gen 3                   6.7      99999.0
# 2  Snapdragon 8 Gen 3                   6.2      74999.0

# %%
df.rename(columns={"RAM (GB)":"RAM","Screen Size (inches)":"Screen","Price (INR)":"Price"},inplace=True)
print(df.columns)
# Out:
# Index(['S.No', 'Brand', 'Model Name', 'Color', 'RAM', 'ROM (GB)', 'Processor',
#        'Screen', 'Price'],
#       dtype='object')

# %% [markdown]
# **Handle strings**

# %%
df['Model Name']=df['Model Name'].str.strip()
df['Brand']=df['Brand'].str.lower()
print(df.head())
# Out:
#    S.No    Brand        Model Name            Color  RAM  ROM (GB)  \
# 0     1  samsung  Galaxy S24 Ultra   Titanium Black   12       256
# 1     2  samsung       Galaxy S24+    Cobalt Violet   12       256
# 2     3  samsung        Galaxy S24      Marble Gray    8       128
# 3     4  samsung        Galaxy A55     Awesome Navy    8       128
# 4     5  samsung        Galaxy A35  Awesome Iceblue    6       128
#
#             Processor  Screen     Price
# 0  Snapdragon 8 Gen 3     6.8  124999.0
# 1  Snapdragon 8 Gen 3     6.7   99999.0
# 2  Snapdragon 8 Gen 3     6.2   74999.0
# 3         Exynos 1480     6.6   38999.0
# 4         Exynos 1380     6.6   30999.0

# %% [markdown]
# **Handle inconsistent values**

# %%
lst=[
    ['praffull','male'],
    ['sharayu','f'],
    ['shailaja','female'],
    ['megha','female'],
    ['soham','m']
]
df=pandas.DataFrame(lst)
print(df)
# Out:
#           0       1
# 0  praffull    male
# 1   sharayu       f
# 2  shailaja  female
# 3     megha  female
# 4     soham       m

# %%
df[1]=df[1].replace({
    "M":"Male","m":"Male","male":"Male",
    "F":"Female","f":"Female","female":"Female"
})
print(df)
# Out:
#           0       1
# 0  praffull    Male
# 1   sharayu  Female
# 2  shailaja  Female
# 3     megha  Female
# 4     soham    Male

# %% [markdown]
# **handling dates - later**

# %% [markdown]
# **Drop unwanted rows and columns**

# %%
df=pandas.read_pickle("mobilestock")
print(df.head(3))
print(df.shape)
# Out:
#    S.No    Brand        Model Name           Color  RAM (GB)  ROM (GB)  \
# 0     1  Samsung  Galaxy S24 Ultra  Titanium Black        12       256
# 1     2  Samsung       Galaxy S24+   Cobalt Violet        12       256
# 2     3  Samsung        Galaxy S24     Marble Gray         8       128
#
#             Processor  Screen Size (inches)  Price (INR)
# 0  Snapdragon 8 Gen 3                   6.8     124999.0
# 1  Snapdragon 8 Gen 3                   6.7      99999.0
# 2  Snapdragon 8 Gen 3                   6.2      74999.0
# (50, 9)

# %%
res=df[df['RAM (GB)']>10]
print(res.shape)
print(res)
# Out:
# (21, 9)
#     S.No     Brand          Model Name            Color  RAM (GB)  ROM (GB)  \
# 0      1   Samsung    Galaxy S24 Ultra   Titanium Black        12       256
# 1      2   Samsung         Galaxy S24+    Cobalt Violet        12       256
# 13    14   OnePlus                  12      Silky Black        12       256
# 17    18   OnePlus                Open     Emerald Dusk        16       512
# 18    19    Xiaomi            14 Ultra            White        16       512
# 19    20    Xiaomi                  14            Black        12       256
# 20    21    Xiaomi              13 Pro    Ceramic Black        12       256
# 21    22    Xiaomi  Redmi Note 13 Pro+     Fusion White        12       256
# 25    26      Vivo            X100 Pro   Asteroid Black        16       512
# 26    27      Vivo                X100   Startrail Blue        12       256
# 27    28      Vivo             V30 Pro    Peacock Green        12       256
# ...

# %%
res=df.drop(columns=['S.No','Color','Processor'])
print(res.head(3))
# Out:
#      Brand        Model Name  RAM (GB)  ROM (GB)  Screen Size (inches)  \
# 0  Samsung  Galaxy S24 Ultra        12       256                   6.8
# 1  Samsung       Galaxy S24+        12       256                   6.7
# 2  Samsung        Galaxy S24         8       128                   6.2
#
#    Price (INR)
# 0     124999.0
# 1      99999.0
# 2      74999.0

# %%
res=df[df['RAM (GB)']>10]
print(res.shape)
res.reset_index(drop=True,inplace=True)
print(res)
# Out:
# (21, 9)
#     S.No     Brand          Model Name            Color  RAM (GB)  ROM (GB)  \
# 0      1   Samsung    Galaxy S24 Ultra   Titanium Black        12       256
# 1      2   Samsung         Galaxy S24+    Cobalt Violet        12       256
# 2     14   OnePlus                  12      Silky Black        12       256
# 3     18   OnePlus                Open     Emerald Dusk        16       512
# 4     19    Xiaomi            14 Ultra            White        16       512
# 5     20    Xiaomi                  14            Black        12       256
# 6     21    Xiaomi              13 Pro    Ceramic Black        12       256
# 7     22    Xiaomi  Redmi Note 13 Pro+     Fusion White        12       256
# 8     26      Vivo            X100 Pro   Asteroid Black        16       512
# 9     27      Vivo                X100   Startrail Blue        12       256
# 10    28      Vivo             V30 Pro    Peacock Green        12       256
# ...

# %% [markdown]
# **Final Verification**

# %%
print(df.isnull().sum().sum())
print(df.duplicated().sum())
# Out:
# 0
# 0
