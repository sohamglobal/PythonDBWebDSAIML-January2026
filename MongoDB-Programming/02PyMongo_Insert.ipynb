# %%
pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.16.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10.0 kB)
# Collecting dnspython<3.0.0,>=2.6.1 (from pymongo)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading pymongo-4.16.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 19.6 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 15.2 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.8.0 pymongo-4.16.0

# %%
from pymongo import MongoClient

# %%
client=MongoClient("mongodb+srv://praffull:mongodb913@sharayucluster.fib907c.mongodb.net/?appName=sharayucluster")

# %%
db1=client["spiderdb"]

# %%
coll1=db1["workers"]

# %%
nm=input('Enter worker name : ')
dp=input('Enter department : ')
ps=input('Enter post : ')
lo=input('Enter location : ')
sl=int(input('Enter salary : '))
# Out:
# Enter worker name : dominik szoboszlai
# Enter department : sales
# Enter post : executive
# Enter location : rome
# Enter salary : 55300

# %%
dic={}
dic['name']=nm
dic['department']=dp
dic['post']=ps
dic['location']=lo
dic['salary']=sl
print(dic)
# Out:
# {'name': 'dominik szoboszlai', 'department': 'sales', 'post': 'executive', 'location': 'rome', 'salary': 55300}

# %%
coll1.insert_one(dic)
print('New worker added to mongodb collection')
# Out:
# New worker added to mongodb collection

# %%
db2=client["sohamdb"]

# %%
coll2=db2["users"]

# %%
uid=input('Enter userid : ')
ps=input('Enter password : ')
nm=input('Enter user name : ')
hob=[]
for i in range(1,4):
  h=input('Enter hobby : ')
  hob.append(h)
# Out:
# Enter userid : praffull
# Enter password : chelsea
# Enter user name : ethan hunt
# Enter hobby : football
# Enter hobby : travel
# Enter hobby : music

# %%
dic={}
dic['userid']=uid
dic['password']=ps
dic['name']=nm
dic['hobbies']=hob
print(dic)
# Out:
# {'userid': 'praffull', 'password': 'chelsea', 'name': 'ethan hunt', 'hobbies': ['football', 'travel', 'music']}

# %%
coll2.insert_one(dic)
print('New user added...')
# Out:
# New user added...

# %%
collstud=db2["students"]

# %%
nm=input('Enter name : ')
co=input('Enter course : ')
fs=float(input('Enter fees : '))
# Out:
# Enter name : shailaja
# Enter course : asp.net mvc
# Enter fees : 7500

# %%
dic={}
dic['studentname']=nm
dic['course']=co
dic['fees']=fs
print(dic)
# Out:
# {'studentname': 'shailaja', 'course': 'asp.net mvc', 'fees': 7500.0}

# %%
collstud.insert_one(dic)
print('new students registered')
# Out:
# new students registered
