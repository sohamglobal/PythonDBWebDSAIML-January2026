# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 20.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 24.2 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient

# %%
client=MongoClient("mongodb+srv://praffull:mongodb913@sharayucluster.fib907c.mongodb.net/?appName=sharayucluster")

# %%
db=client["sohamdb"]

# %%
coll=db["students"]

# %%
for doc in coll.find():
  print(doc)
# Out:
# {'_id': ObjectId('69a79a6a68e7db26797c2909'), 'studentname': 'sharayu', 'course': 'spring boot', 'fees': 9500}
# {'_id': ObjectId('69ae2d09e9a68698eb7c2907'), 'studentname': 'soham', 'course': 'machine learning', 'tools': ['python', 'scikit learn', 'tensorflow', 'pandas'], 'fees': 12000}

# %%
coll1=db["users"]

# %%
for doc in coll1.find():
  print(doc)
# Out:
# {'_id': ObjectId('69a8e5a10aae5520447c2907'), 'userid': 'buttler', 'password': 'england', 'age': 35, 'name': 'jos buttler', 'gender': 'male', 'email': 'jos@outlook.com'}
# {'_id': ObjectId('69a8eacd0aae5520447c2909'), 'userid': 'haaland', 'password': 'norway', 'age': 24, 'name': 'Erling Haaland', 'gender': 'male', 'email': 'haaland@gmail.com', 'hobbies': ['football', 'gym', 'gaming']}
# {'_id': ObjectId('69a8eacd0aae5520447c290a'), 'userid': 'salah', 'password': 'egypt', 'age': 32, 'name': 'Mohamed Salah', 'gender': 'male', 'email': 'salah@gmail.com', 'hobbies': ['reading', 'football', 'fitness']}
# {'_id': ObjectId('69a8eacd0aae5520447c290b'), 'userid': 'debruyne', 'password': 'belgium', 'age': 33, 'name': 'Kevin De Bruyne', 'gender': 'male', 'email': 'kevin@outlook.com', 'hobbies': ['cycling', 'music', 'football']}
# ...

# %%
for doc in coll1.find():
  print(f"Name : {doc['name']} | Age : {doc['age']}")
# Out:
# Name : jos buttler | Age : 35
# Name : Erling Haaland | Age : 24
# Name : Mohamed Salah | Age : 32
# Name : Kevin De Bruyne | Age : 33
# Name : Marcus Rashford | Age : 27
# Name : Bruno Fernandes | Age : 30
# Name : Martin Odegaard | Age : 26
# Name : Son Heung Min | Age : 31
# Name : Raheem Sterling | Age : 30
# Name : Virgil Van Dijk | Age : 33
# Name : Alisson Becker | Age : 32
# Name : Alexis Sanchez | Age : 29
# Name : Gabriel Jesus | Age : 25
# Name : Gabriel Martinelli | Age : 23
# Name : Morgan White | Age : 28
# Name : Taylor Green | Age : 31
# Name : Harry Kane | Age : 31
# Name : Phil Foden | Age : 24
# Name : Declan Rice | Age : 26
# Name : Kyle Walker | Age : 34
# Name : Bernardo Silva | Age : 30

# %%
for doc in coll1.find():
  try:
    print(f"Name : {doc['name']} | Hobbies : {doc['hobbies']}")
  except:
    pass
# Out:
# Name : Erling Haaland | Hobbies : ['football', 'gym', 'gaming']
# Name : Mohamed Salah | Hobbies : ['reading', 'football', 'fitness']
# Name : Kevin De Bruyne | Hobbies : ['cycling', 'music', 'football']
# Name : Marcus Rashford | Hobbies : ['charity', 'football', 'reading']
# Name : Bruno Fernandes | Hobbies : ['gaming', 'football', 'travel']
# Name : Martin Odegaard | Hobbies : ['football', 'music', 'movies']
# Name : Son Heung Min | Hobbies : ['fitness', 'football', 'travel']
# Name : Raheem Sterling | Hobbies : ['cars', 'football', 'music']
# Name : Virgil Van Dijk | Hobbies : ['gym', 'football', 'swimming']
# Name : Alisson Becker | Hobbies : ['music', 'football', 'church']
# Name : Alexis Sanchez | Hobbies : ['yoga', 'reading', 'travel']
# Name : Gabriel Jesus | Hobbies : ['football', 'gaming', 'music']
# Name : Gabriel Martinelli | Hobbies : ['football', 'movies', 'travel']
# Name : Morgan White | Hobbies : ['photography', 'fitness', 'blogging']
# ...

# %%
db2=client["spiderdb"]

# %%
coll2=db2["workers"]

# %%
for doc in coll2.find():
  print(doc)
# Out:
# {'_id': ObjectId('69a7980668e7db26797c2907'), 'name': 'mitchell santner', 'department': 'admin', 'post': 'manager', 'location': 'kolkata', 'salary': 45000}
# {'_id': ObjectId('69a798db68e7db26797c2908'), 'name': 'glenn phillips', 'department': 'sales', 'post': 'executive', 'mobile': '9765543866'}

# %%
for doc in coll2.find():
  print(doc['name'])
# Out:
# mitchell santner
# glenn phillips

# %%
coll4=db2["films"]

# %%
gen=input('Enter genre to search : ')
condition={}
condition['category']=gen
print(condition)
# Out:
# Enter genre to search : action
# {'category': 'action'}

# %%
for doc in coll4.find(condition):
  print(doc)
# Out:
# {'_id': '151', 'filmnm': 'sholay', 'category': 'action', 'releaseyr': 1975, 'written': 'salim javed', 'director': 'ramesh sippy', 'actor': 'amitabh bachchan', 'actress': 'jaya bhaduri', 'music': 'r d burman', 'villain': 'amjad khan', 'budgetmn': 30, 'collectionmn': 410}
# {'_id': '153', 'filmnm': 'the matrix', 'category': 'action', 'releaseyr': 1999, 'director': 'wachowski bros', 'actor': 'keanu reeves', 'actress': 'carrie-anne moss', 'budgetmn': 4725, 'collectionmn': 34950}
# {'_id': '155', 'filmnm': 'mi5 rogue nation', 'category': 'action', 'releaseyr': 2015, 'director': 'christopher mcquarrie', 'actor': 'tom cruise', 'actress': 'rebeccca ferguson', 'budgetmn': 11250, 'collectionmn': 51225}
