# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 23.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 23.5 MB/s eta 0:00:00
# ...

# %%
import pandas
from pymongo import MongoClient

# %%
client=MongoClient("mongodb+srv://praffull:mongodb913@sharayucluster.fib907c.mongodb.net/?appName=sharayucluster")

# %%
db=client["spiderdb"]

# %%
coll_films=db["films"]

# %%
data=list(coll_films.find())
print(data)
# Out:
# [{'_id': '151', 'filmnm': 'sholay', 'category': 'action', 'releaseyr': 1975, 'written': 'salim javed', 'director': 'ramesh sippy', 'actor': 'amitabh bachchan', 'actress': 'jaya bhaduri', 'music': 'r d burman', 'villain': 'amjad khan', 'budgetmn': 30, 'collectionmn': 410}, {'_id': '152', 'filmnm': 'pk', 'category': 'comedy', 'releaseyr': 2014, 'director': 'rajkumar hirani', 'actor': 'amir khan', 'actress': 'anushka sharma', 'budgetmn': 850, 'collectionmn': 8540}, {'_id': '153', 'filmnm': 'the matrix', 'category': 'action', 'releaseyr': 1999, 'director': 'wachowski bros', 'actor': 'keanu reeves', 'actress': 'carrie-anne moss', 'budgetmn': 4725, 'collectionmn': 34950}, {'_id': '154', 'filmnm': 'mughal e azam', 'category': 'romance', 'releaseyr': 1960, 'director': 'k asif', 'actor': 'dilip kumar', 'actress': 'madhubala', 'music': 'naushad', 'budgetmn': 15, 'collectionmn': 110}, {'_id': '155', 'filmnm': 'mi5 rogue nation', 'category': 'action', 'releaseyr': 2015, 'director': 'christopher 
# ...

# %%
df=pandas.DataFrame(data)
print(df)
# Out:
#     _id                filmnm category  releaseyr      written  \
# 0   151                sholay   action       1975  salim javed
# 1   152                    pk   comedy       2014          NaN
# 2   153            the matrix   action       1999          NaN
# 3   154         mughal e azam  romance       1960          NaN
# 4   155      mi5 rogue nation   action       2015          NaN
# 5   156                  maya  romance       1961          NaN
# 6   157     1942 a love story  romance       1994          NaN
# 7   158  chalti ka naam gaadi   comedy       1958          NaN
# 8   159             golmaal 3   comedy       2010          NaN
# 9   160                 bhoot   horror       2003          NaN
# 10  161               silsila  romance       1981          NaN
# 11  162                swades    drama       2004          NaN
# 12  163                  1917      war       2019          NaN
#
#                  director             actor              actress  \
# ...

# %%
coll_emp=db["workers"]
empdata=list(coll_emp.find())
dfemp=pandas.DataFrame(empdata)
print(dfemp)
# Out:
#                         _id                name department       post  \
# 0  69a7980668e7db26797c2907    mitchell santner      admin    manager
# 1  69a798db68e7db26797c2908      glenn phillips      sales  executive
# 2  69af7e6884b1f0d70e91914e         pat cummins  marketing    manager
# 3  69af7eb584b1f0d70e91914f  dominik szoboszlai      sales  executive
#
#   location   salary      mobile
# 0  kolkata  45000.0         NaN
# 1      NaN      NaN  9765543866
# 2  chicago  61200.0         NaN
# 3    paris  55300.0         NaN
