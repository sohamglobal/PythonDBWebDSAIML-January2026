# %%
n=int(input('Enter a number : '))
sq=n*n
print(f"square of {n} is {sq}")
# Out:
# Enter a number : soham
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-174603815.py in <cell line: 0>()
# ----> 1 n=int(input('Enter a number : '))
#       2 sq=n*n
#       3 print(f"square of {n} is {sq}")
#
# ValueError: invalid literal for int() with base 10: 'soham'

# %% [markdown]
# Exception Handling

# %%
try:
  n=int(input('Enter a number : '))
except:
  print("Invalid input...please enter a number")
  n=0

sq=n**2
print(f"square of {n} is {sq}")
# Out:
# Enter a number : soham
# Invalid input...please enter a number
# square of 0 is 0

# %%
custnm=input('Enter customer name : ')

try:
  purchamt=float(input('Enter purchase amount : '))
except ValueError:
  print('invalid purchase amount')
  purchamt=0

discount=purchamt*10/100
bill=purchamt-discount

print(f"{custnm}, your net bill is {bill}")
# Out:
# Enter customer name : sharayu
# Enter purchase amount : java
# invalid purchase amount
# sharayu, your net bill is 0.0
