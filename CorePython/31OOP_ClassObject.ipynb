# %%
class Person:
  def welcome(self):
    print("welcome to python OOP")
  def thanks(self,nm):
    print(f"thanks {nm} for joining sohamglobal")

# %%
welcome()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-241228648.py in <cell line: 0>()
# ----> 1 welcome()
#
# NameError: name 'welcome' is not defined

# %%
# Person p; -> C++
# Person person=new Person(); -> Java
obj=Person()

# %%
obj.welcome() # if self is mission in the function
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-485918977.py in <cell line: 0>()
# ----> 1 obj.welcome()
#
# TypeError: Person.welcome() takes 0 positional arguments but 1 was given

# %%
obj.welcome()
# Out:
# welcome to python OOP

# %%
obj.thanks("sharayu")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-962667529.py in <cell line: 0>()
# ----> 1 obj.thanks("sharayu")
#
# TypeError: Person.thanks() takes 1 positional argument but 2 were given

# %%
obj.thanks("sharayu")
# Out:
# thanks sharayu for joining sohamglobal

# %%
class Calculator:
  def calcsquare(self,n):
    sq=n**2
    print(f"square of {n} is {sq}")
  def multiple(self,x,y):
    res=x*y
    print(f"multiplication of {x} and {y} is {res}")
  def add(self,x,y):
    res=x+y
    print(f"addition of {x} and {y} is {res}")

# %%
obj=Calculator()

# %%
obj.multiple(12,23)
# Out:
# multiplication of 12 and 23 is 276
