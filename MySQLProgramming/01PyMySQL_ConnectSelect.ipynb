# %% [markdown]
# **install additional library to connect python with MySQL database**

# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading pymysql-1.1.2-py3-none-any.whl.metadata (4.3 kB)
# Downloading pymysql-1.1.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.2

# %% [markdown]
# import the module in the code

# %%
import pymysql

# %% [markdown]
# Connect to MySQL database

# %%
connection=pymysql.connect(host='pymyservice-mysql-python-0226.g.aivencloud.com',port=17577,user='praffull',password='AVNS_wBJdNDhkoHduUD3Z3z2',database='sharayudb')
print('connected to cloud MySQL successfully')
# Out:
# connected to cloud MySQL successfully

# %%
cursor=connection.cursor()

# %%
cursor.execute("select * from patients")
data=cursor.fetchall()
print(data)
# Out:
# ((101, 'Alice', 45, 'Heart Disease', 1), (102, 'Bob', 50, 'Heart Attack', 1), (103, 'Charlie', 60, 'Stroke', 2), (104, 'David', 38, 'Migraine', 2), (105, 'Emma', 25, 'Fracture', 3), (106, 'Frank', 30, 'Back Pain', 3), (107, 'Grace', 22, 'Skin Allergy', 4), (108, 'Hannah', 5, 'Fever', 5), (109, 'Ian', 7, 'Cold', 5), (110, 'Jack', 65, 'Heart Disease', 1), (111, 'Kathy', 55, 'Brain Tumor', 2), (112, 'Leo', 40, 'Fracture', 3), (113, 'Mona', 29, 'Acne', 4), (114, 'Nina', 33, 'Eczema', 4), (115, 'Oscar', 4, 'Flu', 5), (116, 'Paul', 48, 'Heart Block', 1), (117, 'Queen', 52, 'Epilepsy', 2), (118, 'Ravi', 37, 'Back Pain', 3), (119, 'Sara', 41, 'Unknown Illness', None), (120, 'Tom', 36, 'General Checkup', None))

# %%
cursor.execute("select * from customers")
data=cursor.fetchall()
print(data)
# Out:
# ((1, 'Joe Root', 'london', 'sk181', 'netbanking'), (2, 'Boris Becker', 'berlin', 'ho162', 'cash'), (3, 'Michael Schumacher', 'berlin', 'bm201', 'credit card'), (4, 'Arnold Schwarzenegger', 'los angles', 'to191', 'credit card'), (5, 'Jos Buttler', 'manchester', 'vw173', 'credit card'), (6, 'Rebecca Ferguson', 'new york', 'bm185', 'netbanking'), (7, 'Steffi Graff', 'stuttgart', 'vw171', 'debit card'), (8, 'Keanu Reeves', 'tokyo', 'to191', 'credit card'), (9, 'Sabastian Vettel', 'heppenheim', 'sk183', 'credit card'), (10, 'Tom Cruise', 'chicago', 'bm201', 'cash'), (11, 'Roger Federer', 'amsterdam', 'ho161', 'credit card'), (12, 'Emily Blunt', 'london', 'vw172', 'credit card'), (13, 'Shah Rukh Khan', 'new delhi', 'tt153', 'debit card'), (14, 'A R Rahman', 'chennai', 'hd142', 'cash'), (15, 'Tabu', 'hyderabad', 'vw173', 'debit card'), (16, 'Shabana Azmi', 'mumbai', 'ss210', 'debit card'), (17, 'Rekha', 'chennai', 'hd141', 'cash'), (18, 'Amitabh Bachchan', 'allahabad', 'cs682', 'cash'), (19, 'Imran Khan', 'lahore', 'to191', 'netbanking'), (20, 'Dipika Singh', 'mumbai', 'to193', 'netbanking'), (21, 'Alia Bhat', 'lucknow', 'hd142', 'cash'), (22, 'Serena Williams', 'new york', 'ss210', 'netbanking'), (23, 'Max Verstappen', 'berlin', 'rb739', 'cash'), (24, 'Charles Leclerc', 'monte carlo', 'fr133', 'debit card'), (25, 'Sylvester Stallone', 'Kolkata', 'ms134', 'cash'), (26, 'Emily Blunt', 'Agra', 'ms131', 'netbanking'))

# %%
cursor.execute("select * from doctors")
data=cursor.fetchall()
print(data)
# Out:
# ((1, 'Dr. Smith', 'Cardiologist', 15), (2, 'Dr. Johnson', 'Neurologist', 12), (3, 'Dr. Williams', 'Orthopedic', 10), (4, 'Dr. Brown', 'Dermatologist', 8), (5, 'Dr. Taylor', 'Pediatrician', 6))

# %%
connection.close()
