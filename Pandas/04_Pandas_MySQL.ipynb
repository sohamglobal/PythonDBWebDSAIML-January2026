# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading pymysql-1.1.3-py3-none-any.whl.metadata (4.3 kB)
# Downloading pymysql-1.1.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.3

# %%
import pandas
import pymysql

# %%
con=pymysql.connect(host='pymyservice-mysql-python-0226.g.aivencloud.com',port=17577,user='praffull',password='AVNS_wBJdNDhkoHduUD3Z3z2',database='sharayudb')

# %%
df=pandas.read_sql("select * from accounts",con)
# Out:
# /tmp/ipykernel_1615/4042586388.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pandas.read_sql("select * from accounts",con)

# %%
print(df)
# Out:
#     accno                   accnm  acctype  balance
# 0      26                   rohit  saving   24106.0
# 1    1176                Joe Root   saving  54150.0
# 2    1177              Ben Stokes  current  58850.0
# 3    1178          James Anderson    fixed  45000.0
# 4    1179            Stuart Broad      ppf  70000.0
# 5    1180             Jos Buttler   saving  38000.0
# 6    1181            Jofra Archer  current  64000.0
# 7    1182            David Warner    fixed  55000.0
# 8    1183             Steve Smith   saving  73000.0
# 9    1184             Pat Cummins      ppf  47000.0
# 10   1185          Mitchell Starc  current  68000.0
# 11   1186           Glenn Maxwell   saving  42000.0
# 12   1187      Marnus Labuschagne    fixed  51000.0
# 13   1188             Aaron Finch      ppf  36000.0
# 14   1189             Travis Head  current  62000.0
# 15   1190           Cameron Green   saving  49000.0
# 16   1191              Harry Kane    fixed  75000.0
# 17   1192         Raheem Sterling  current  33000.0
# 18   1193         Marcus Rashford   saving  58000.0
# 19   1194         Kevin De Bruyne      ppf  72000.0
# 20   1195           Mohamed Salah  current  67000.0
# 21   1197         Bruno Fernandes    fixed  43000.0
# 22   1198             Bukayo Saka      ppf  52000.0
# 23   1199              Phil Foden   saving  61000.0
# 24   1200             Declan Rice  current  48000.0
# 25   1201           Jack Grealish    fixed  69000.0
# 26   1202        Jordan Henderson   saving  35000.0
# 27   1203             Reece James      ppf  57000.0
# 28   1204         Virgil van Dijk  current  72550.0
# 29   1205          Alisson Becker   saving  46000.0
# 30   1206          Bernardo Silva    fixed  53000.0
# 31   1207           Son Heung-min      ppf  60000.0
# 32   1208         Martin Odegaard   saving  41000.0
# 33   1209           Gabriel Jesus  current  65000.0
# 34   1210               Luke Shaw    fixed  37000.0
# 35   1211               Ben White   saving  54000.0
# 36   1212           Ollie Watkins      ppf  62000.0
# 37   1213          James Maddison  current  44000.0
# 38   1214  Trent Alexander-Arnold   saving  70500.0
# 39   1215         Kalvin Phillips    fixed  59000.0
# 40   1216             Eoin Morgan   saving  30000.0
# 41   1217              Sam Curran  current  56000.0
# 42   1218               Mark Wood    fixed  47000.0
# 43   1219              Alex Carey      ppf  52000.0
# 44   1220          Josh Hazlewood   saving  67500.0
# 45   1221             Nathan Lyon  current  39000.0
# 46   1222            Chris Woakes    fixed  61000.0
# 47   1223          Mitchell Marsh   saving  58000.0
# 48   1224   Dominic Calvert-Lewin      ppf  43000.0
# 49   1226                 Sharayu   saving  46600.0
# 50   1227                Praffull  current  58500.0
# 51   1228                Shailaja   saving  72900.0
# 52   1229              Apurva Deo   saving  82400.0

# %%
df=pandas.read_sql("select * from doctors",con)
print(df)
# Out:
#    doctor_id   doctor_name specialization  experience_years
# 0          1     Dr. Smith   Cardiologist                15
# 1          2   Dr. Johnson    Neurologist                12
# 2          3  Dr. Williams     Orthopedic                10
# 3          4     Dr. Brown  Dermatologist                 8
# 4          5    Dr. Taylor   Pediatrician                 6
# 5          6   Dr. Cummins   Cardiologist                12
# /tmp/ipykernel_1615/2948312494.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pandas.read_sql("select * from doctors",con)

# %%
con.close()
